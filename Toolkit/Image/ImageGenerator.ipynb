# %%
import os  
import keras 
import numpy
import PIL  ##  圖片處理套件
import matplotlib  ##  圖片呈現套件
Path = "C:\\Users\\user\\Desktop\\Python\\Toolkit\\Image\\data\\"
File = os.listdir(path)

# %%
objectImage = [PIL.Image.open(Path + i) for i in File]
arrayImage  = [numpy.array(i) for i in objectImage]

matplotlib.pyplot.imshow(arrayImage[0])

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=40)
